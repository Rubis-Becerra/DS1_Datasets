# %% [markdown]
# 📘 Introducción
#
# En el presente notebook se avanza en adquirir conocimientos de Bases de Python, cuyo objetivo es identificar y analizar datasets potenciales para su posterior desarrollo analítico.
#
# Se seleccionaron tres datasets de diversos rubros, lo cuales fueron obtenidos y alojados en un repositorio de GitHub, y serán cargados utilizando la librería Pandas.
#
# A lo largo del notebook se realizará una exploración inicial de cada dataset y se describirán las variables que resulten más relevantes desde una perspectiva comercial y analítica, considerando posibles casos de uso en contextos empresariales.

# %% [markdown]
# Analisis Exploratorio del Dataset 1:

# %%
import pandas as pd

# %%
df_beauty = pd.read_csv("../data/beauty_sales_unilever.csv")
df_beauty.head()
# Out:
#          date     brand product_type  skin_type hair_type    country  \
# 0  2022-01-01  TRESemmé    Body Wash  Sensitive      Wavy     Mexico
# 1  2022-01-02    Rexona    Body Wash       Oily  Straight     Mexico
# 2  2022-01-03     Sedal    Hair Mask     Normal      Wavy  Argentina
# 3  2022-01-04     Sedal    Deodorant  Sensitive     Curly     Mexico
# 4  2022-01-05  TRESemmé      Shampoo        Dry     Coily      Chile
#
#   sales_channel  units_sold  unit_price_usd  cost_usd  discount_pct  \
# 0     Wholesale         753           14.73      1.32         11.20
# 1   Supermarket        4571            2.80      5.14         20.72
# 2     Wholesale        1426            9.75      8.63          6.55
# 3   Supermarket        3479           17.66      6.27         15.07
# 4      Pharmacy        5630            5.29      8.72          9.72
#
#    marketing_spend_usd  on_promotion  customer_rating  returns_units  \
# ...

# %%
df_beauty.shape
# Out:
# (3200, 18)

# %%
df_beauty.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3200 entries, 0 to 3199
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   date                 3200 non-null   object
#  1   brand                3200 non-null   object
#  2   product_type         3200 non-null   object
#  3   skin_type            3200 non-null   object
#  4   hair_type            3200 non-null   object
#  5   country              3200 non-null   object
#  6   sales_channel        3200 non-null   object
#  7   units_sold           3200 non-null   int64
#  8   unit_price_usd       3200 non-null   float64
#  9   cost_usd             3200 non-null   float64
#  10  discount_pct         3200 non-null   float64
#  11  marketing_spend_usd  3200 non-null   float64
#  12  on_promotion         3200 non-null   int64
#  13  customer_rating      3200 non-null   float64
#  14  returns_units        3200 non-null   int64
# ...

# %% [markdown]
# 💄 Contexto del Dataset – Beauty Sales (Enfoque Unilever)
#
# El dataset contiene información sobre ventas de productos de cuidado personal y belleza, incluyendo variables relacionadas con características del producto, comportamiento del consumidor, estrategias comerciales y desempeño financiero. Este dataset es muy relevante para explorar empresas de consumo masivo, ya que posibilita evaluar el impacto de las estrategias de pricing, promociones, marketing y gestión de stock sobre los resultados comerciales, así como identificar oportunidades de optimización y crecimiento del negocio.

# %% [markdown]
# 🔍 Variables Relevantes para el Análisis Comercial y Analítico
#
# -date: análisis temporales, identificar tendencias de ventas y estacionalidad.
#
# -brand: comparar el desempeño comercial entre distintas marcas del portafolio.
#
# -product_type: analizar el comportamiento de diferentes categorías de productos de belleza.
#
# -skin_type y hair_type: clave para segmentación del mercado según las necesidades del consumidor.
#
# -country: análisis geográfico y comparación de resultados entre mercados.
#
# -sales_channel: evaluar la efectividad de los distintos canales de venta.
#
# -units_sold: medición del volumen de ventas.
#
# -unit_price_usd: análisis de pricing y posicionamiento de producto.
#
# -discount_pct y on_promotion: analisis del impacto de las promociones sobre las ventas y la rentabilidad.
#
# -marketing_spend_usd: evaluar la eficiencia del gasto en marketing.
#
# -revenue_usd y profit_usd: análisis financiero y de rentabilidad.
#
# -customer_rating: aporta información sobre la percepción del cliente y la calidad del producto.
#
# -returns_units: análisis de devoluciones y posibles problemas de satisfacción o calidad.
#
# -stock_level: gestión de inventarios y planificación de la demanda.
#
# En conjunto, estas variables permiten desarrollar análisis orientados a la optimización comercial, rentabilidad, experiencia del cliente y la toma de decisiones estratégicas en el sector de belleza y cuidado personal.

# %% [markdown]
# Analisis Exploratorio del Dataset 2:

# %%
df_pharma = pd.read_csv("../data/pharma_data_retail.csv")
df_pharma.head()
# Out:
#               Distributor                                      Customer Name  \
# 0  Gottlieb-Cruickshank    Hahn, Rutherford and Gislason Pharmaceutical L...
# 1              Smith Inc                                   Schmitt LLC Pharm
# 2         Prohaska-Kuhic   Spinka, Schowalter and Conn Pharmaceutical Lim...
# 3  Gottlieb-Cruickshank                Denesik, Walter and Beatty Pharma Plc
# 4              Smith Inc                        Lesch PLC Pharmaceutical Ltd
#
#                 City Country  Latitude  Longitude   Channel  Sub-channel  \
# 0      Łaziska Górne  Poland   50.1500    18.8333  Hospital      Private
# 1               Nysa  Poland   50.4738    17.3344  Pharmacy       Retail
# 2           Biłgoraj  Poland   50.5500    22.7333  Pharmacy  Institution
# 3  Ostrów Mazowiecka  Poland   52.8000    21.9000  Pharmacy  Institution
# 4           Głuszyca  Poland   50.6874    16.3717  Pharmacy       Retail
#
# ...

# %%
df_pharma.shape
# Out:
# (2500, 18)

# %%
df_pharma.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Distributor        2500 non-null   object
#  1   Customer Name      2500 non-null   object
#  2   City               2500 non-null   object
#  3   Country            2500 non-null   object
#  4   Latitude           2500 non-null   float64
#  5   Longitude          2500 non-null   float64
#  6   Channel            2500 non-null   object
#  7   Sub-channel        2500 non-null   object
#  8   Product Name       2500 non-null   object
#  9   Product Class      2500 non-null   object
#  10  Quantity           2500 non-null   float64
#  11  Price              2500 non-null   int64
#  12  Sales              2500 non-null   float64
#  13  Month              2500 non-null   object
#  14  Year               2500 non-null   int64
#  15  Name of Sales Rep  2500 non-null   object
# ...

# %% [markdown]
# 📦 Contexto del Dataset – Ventas y Distribución Comercial farmacéutica
#
# El dataset contiene información vinculada a ventas y distribución comercial, incluyendo datos de clientes, productos, canales de venta, equipos comerciales y ubicación geográfica. Este dataset resulta especialmente útil para analizar empresas con redes de distribución amplias, ya que posibilita evaluar la eficiencia de los canales de venta, el rendimiento del equipo comercial, la performance de productos y el comportamiento de los clientes en distintos mercados y regiones.

# %% [markdown]
# 🔍 Variables Relevantes para el Análisis
#
# -Distributor: evaluar desempeño de los distintos distribuidores y su aporte a las ventas totales.
#
# -Customer Name: estudiar el comportamiento de compra de los clientes y su contribución al negocio.
#
# -City y Country: exploraciones geográficas y comparaciones regionales.
#
# -Latitude y Longitude: realizar análisis espaciales y visualizaciones geográficas de las ventas.
#
# -Channel y Sub-channel: evaluar la efectividad de los distintos canales de comercialización.
#
# -Product Name y Product Class: analizar el desempeño de productos y categorías.
#
# -Quantity: volumen de unidades vendidas.
#
# -Price: análisis de precios y estrategias comerciales.
#
# -Sales: evaluar el ingreso generado.
#
# -Month y Year: posibilitan análisis temporales, tendencias y estacionalidad.
#
# -Name of Sales Rep, Manager y Sales Team: permiten evaluar el rendimiento del equipo comercial y la estructura organizacional de ventas.
#
# En general, estas variables permiten desarrollar análisis orientados a la optimización de la fuerza de ventas, la eficiencia de los canales de distribución, la gestión de clientes y la toma de decisiones estratégicas en el área comercial.

# %% [markdown]
# Analisis Exploratorio del Dataset 3:

# %%
df_renewable_energy = pd.read_csv("../data/renewable_energy.csv")
df_renewable_energy.head()
# Out:
#    ObjectId             Country ISO2   ISO3                       Indicator  \
# 0         1  Advanced Economies  NaN  AETMP          Electricity Generation
# 1         2  Advanced Economies  NaN  AETMP  Electricity Installed Capacity
# 2         3  Advanced Economies  NaN  AETMP          Electricity Generation
# 3         4  Advanced Economies  NaN  AETMP  Electricity Installed Capacity
# 4         5  Advanced Economies  NaN  AETMP          Electricity Generation
#
#                           Technology          Energy_Type  \
# 0                          Bioenergy      Total Renewable
# 1                          Bioenergy      Total Renewable
# 2                       Fossil fuels  Total Non-Renewable
# 3                       Fossil fuels  Total Non-Renewable
# 4  Hydropower (excl. Pumped Storage)      Total Renewable
#
#                    Unit                                             Source  \
# 0  Gigawatt-hours (GWh)  International Renewable Energy Agency (IRENA) ...
# ...

# %%
df_renewable_energy.shape
# Out:
# (2062, 36)

# %%
df_renewable_energy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2062 entries, 0 to 2061
# Data columns (total 36 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ObjectId             2062 non-null   int64
#  1   Country              2062 non-null   object
#  2   ISO2                 1790 non-null   object
#  3   ISO3                 2062 non-null   object
#  4   Indicator            2062 non-null   object
#  5   Technology           2062 non-null   object
#  6   Energy_Type          2062 non-null   object
#  7   Unit                 2062 non-null   object
#  8   Source               2062 non-null   object
#  9   CTS_Name             2062 non-null   object
#  10  CTS_Code             2062 non-null   object
#  11  CTS_Full_Descriptor  2062 non-null   object
#  12  F2000                1414 non-null   float64
#  13  F2001                1444 non-null   float64
#  14  F2002                1468 non-null   float64
# ...

# %% [markdown]
# ⚡ Contexto del Dataset – Indicadores Energéticos y Tecnológicos
#
# El presente dataset contiene información sobre indicadores energéticos a nivel país, desagregados por tipo de energía, tecnología e indicador, con datos históricos que abarcan el período comprendido entre los años 2000 y 2023.Los registros permiten analizar la evolución temporal de distintos indicadores energéticos, facilitando la comparación entre países y tecnologías, así como el estudio de tendencias de largo plazo en la producción, consumo o adopción de diferentes fuentes de energía, permitiendo estimar el desempeño energético de los países y su transición hacia tecnologías más eficientes y sustentables.

# %% [markdown]
# 🔍 Variables Relevantes para el Análisis
#
# -Country: permite realizar comparaciones entre países y analizar diferencias en desempeño energético.
#
# -ISO2 y ISO3: facilitan la estandarización de países para cruces con otras bases de datos.
#
# -Indicator: tipo de métrica energética analizada.
#
# -Technology: permite evaluar el comportamiento y evolución de distintas tecnologías energéticas.
#
# -Energy_Type: analizar diferencias entre fuentes de energía (renovables y no renovables).
#
# -Unit: información sobre la unidad de medida de los indicadores.
#
# -Source: permite identificar el origen de los datos y su confiabilidad.
#
# -CTS_Name, CTS_Code y CTS_Full_Descriptor: aportan contexto técnico y descriptivo a los indicadores, facilitando su interpretación.
#
# -F2000 – F2023: conjunto de variables que representan la evolución histórica anual de los indicadores, fundamentales para el análisis de tendencias, crecimiento y cambios estructurales a lo largo del tiempo.
#
# Estas variables permiten desarrollar análisis orientados a la evaluación de tendencias energéticas, la comparación internacional, la planificación estratégica y el apoyo a la toma de decisiones en ámbitos empresariales y gubernamentales.
